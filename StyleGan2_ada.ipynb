# %%
# !nvcc --version
#Make sure cuda version is atleast 11.0
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !git clone 'https://github.com/NVlabs/stylegan2-ada-pytorch'
#Clone the original github repo to access the pretrained model.
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 1.12 MiB | 17.40 MiB/s, done.
# Resolving deltas: 100% (55/55), done.

# %%
#mounting the google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import requests 
file_url = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
    
r = requests.get(file_url, stream = True) 
  
with open("/content/drive/My Drive/cifar-10-python.tar.gz", "wb") as file: 
    for block in r.iter_content(chunk_size = 1024):
         if block: 
             file.write(block)

# %%
# !pip install -q torch==1.8.1 
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# !python '/content/stylegan2-ada-pytorch/dataset_tool.py' --source='/content/drive/MyDrive/cifar-10-python.tar.gz' --dest='/content/stylegan2-ada-pytorch/datasets/cifar10.zip'
# Out:
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)
# Requirement already satisfied: pyspng in /usr/local/lib/python3.7/dist-packages (0.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (1.10.0.post2)
# Requirement already satisfied: imageio-ffmpeg==0.4.3 in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyspng) (1.19.5)
# 100% 50000/50000 [00:18<00:00, 2644.18it/s]

# %% [markdown]
# # Generating Fake Images
#
# It should take roughly 3 minutes to generate each 10000 images in total.This segment creates roughly 3000 images for each class. It can be changed to a higher number to get better metrics.

# %%
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class0 --trunc=1 --seeds=0-3000 --class=0 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class1 --trunc=1 --seeds=0-3000 --class=1 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class2 --trunc=1 --seeds=0-3000 --class=2 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class3 --trunc=1 --seeds=0-3000 --class=3 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class4 --trunc=1 --seeds=0-3000 --class=4 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class5 --trunc=1 --seeds=0-3000 --class=5 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class6 --trunc=1 --seeds=0-3000 --class=6 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class7 --trunc=1 --seeds=0-3000 --class=7 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class8 --trunc=1 --seeds=0-3000 --class=8 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# !python '/content/stylegan2-ada-pytorch/generate.py' --outdir=/content/class9 --trunc=1 --seeds=0-3000 --class=9 \
    --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/cifar10.pkl
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating image for seed 1005 (1005/3001) ...
# Generating image for seed 1006 (1006/3001) ...
# Generating image for seed 1007 (1007/3001) ...
# Generating image for seed 1008 (1008/3001) ...
# Generating image for seed 1009 (1009/3001) ...
# Generating image for seed 1010 (1010/3001) ...
# Generating image for seed 1011 (1011/3001) ...
# Generating image for seed 1012 (1012/3001) ...
# Generating image for seed 1013 (1013/3001) ...
# Generating image for seed 1014 (1014/3001) ...
# Generating image for seed 1015 (1015/3001) ...
# Generating image for seed 1016 (1016/3001) ...
# Generating image for seed 1017 (1017/3001) ...
# Generating image for seed 1018 (1018/3001) ...
# Generating image for seed 1019 (1019/3001) ...
# Generating image for seed 1020 (1020/3001) ...
# Generating image for seed 1021 (1021/3001) ...
# Generating image for seed 1022 (1022/3001) ...
# Generating image for seed 1023 (1023/3001) ...
# Generating image for seed 1024 (1024/3001) ...
# Generating image for seed 1025 (1025/3001) ...
# Generating image for seed 1026 (1026/3001) ...
# Generating image for seed 1027 (1027/3001) ...
# Generating image for seed 1028 (1028/3001) ...
# Generating image for seed 1029 (1029/3001) ...
# Generating image for seed 1030 (1030/3001) ...
# Generating image for seed 1031 (1031/3001) ...
# Generating image for seed 1032 (1032/3001) ...
# Generating image for seed 1033 (1033/3001) ...
# Generating image for seed 1034 (1034/3001) ...
# Generating image for seed 1035 (1035/3001) ...
# Generating image for seed 1036 (1036/3001) ...
# Generating image for seed 1037 (1037/3001) ...
# Generating image for seed 1038 (1038/3001) ...
# Generating image for seed 1039 (1039/3001) ...
# Generating image for seed 1040 (1040/3001) ...
# Generating image for seed 1041 (1041/3001) ...
# Generating image for seed 1042 (1042/3001) ...
# Generating image for seed 1043 (1043/3001) ...
# Generating image for seed 1044 (1044/3001) ...
# Generating image for seed 1045 (1045/3001) ...
# Generating image for seed 1046 (1046/3001) ...
# Generating image for seed 1047 (1047/3001) ...
# Generating image for seed 1048 (1048/3001) ...
# Generating image for seed 1049 (1049/3001) ...
# Generating image for seed 1050 (1050/3001) ...
# Generating image for seed 1051 (1051/3001) ...
# Generating image for seed 1052 (1052/3001) ...
# Generating image for seed 1053 (1053/3001) ...
# Generating image for seed 1054 (1054/3001) ...
# Generating image for seed 1055 (1055/3001) ...
# Generating image for seed 1056 (1056/3001) ...
# Generating image for seed 1057 (1057/3001) ...
# Generating image for seed 1058 (1058/3001) ...
# Generating image for seed 1059 (1059/3001) ...
# Generating image for seed 1060 (1060/3001) ...
# Generating image for seed 1061 (1061/3001) ...
# Generating image for seed 1062 (1062/3001) ...
# Generating image for seed 1063 (1063/3001) ...
# Generating image for seed 1064 (1064/3001) ...
# Generating image for seed 1065 (1065/3001) ...
# Generating image for seed 1066 (1066/3001) ...
# Generating image for seed 1067 (1067/3001) ...
# Generating image for seed 1068 (1068/3001) ...
# Generating image for seed 1069 (1069/3001) ...
# Generating image for seed 1070 (1070/3001) ...
# Generating image for seed 1071 (1071/3001) ...
# Generating image for seed 1072 (1072/3001) ...
# Generating image for seed 1073 (1073/3001) ...
# Generating image for seed 1074 (1074/3001) ...
# Generating image for seed 1075 (1075/3001) ...
# Generating image for seed 1076 (1076/3001) ...
# Generating image for seed 1077 (1077/3001) ...
# Generating image for seed 1078 (1078/3001) ...
# Generating image for seed 1079 (1079/3001) ...
# Generating image for seed 1080 (1080/3001) ...
# Generating image for seed 1081 (1081/3001) ...
# Generating image for seed 1082 (1082/3001) ...
# Generating image for seed 1083 (1083/3001) ...
# Generating image for seed 1084 (1084/3001) ...
# Generating image for seed 1085 (1085/3001) ...
# Generating image for seed 1086 (1086/3001) ...
# Generating image for seed 1087 (1087/3001) ...
# Generating image for seed 1088 (1088/3001) ...
# Generating image for seed 1089 (1089/3001) ...
# Generating image for seed 1090 (1090/3001) ...
# Generating image for seed 1091 (1091/3001) ...
# Generating image for seed 1092 (1092/3001) ...
# Generating image for seed 1093 (1093/3001) ...
# Generating image for seed 1094 (1094/3001) ...
# Generating image for seed 1095 (1095/3001) ...
# Generating image for seed 1096 (1096/3001) ...
# Generating image for seed 1097 (1097/3001) ...
# Generating image for seed 1098 (1098/3001) ...
# Generating image for seed 1099 (1099/3001) ...
# Generating image for seed 1100 (1100/3001) ...
# Generating image for seed 1101 (1101/3001) ...
# Generating image for seed 1102 (1102/3001) ...
# Generating image for seed 1103 (1103/3001) ...
# Generating image for seed 1104 (1104/3001) ...
# Generating image for seed 1105 (1105/3001) ...
# Generating image for seed 1106 (1106/3001) ...
# Generating image for seed 1107 (1107/3001) ...
# Generating image for seed 1108 (1108/3001) ...
# Generating image for seed 1109 (1109/3001) ...
# Generating image for seed 1110 (1110/3001) ...
# Generating image for seed 1111 (1111/3001) ...
# Generating image for seed 1112 (1112/3001) ...
# Generating image for seed 1113 (1113/3001) ...
# Generating image for seed 1114 (1114/3001) ...
# Generating image for seed 1115 (1115/3001) ...
# Generating image for seed 1116 (1116/3001) ...
# Generating image for seed 1117 (1117/3001) ...
# Generating image for seed 1118 (1118/3001) ...
# Generating image for seed 1119 (1119/3001) ...
# Generating image for seed 1120 (1120/3001) ...
# Generating image for seed 1121 (1121/3001) ...
# Generating image for seed 1122 (1122/3001) ...
# Generating image for seed 1123 (1123/3001) ...
# Generating image for seed 1124 (1124/3001) ...
# Generating image for seed 1125 (1125/3001) ...
# Generating image for seed 1126 (1126/3001) ...
# Generating image for seed 1127 (1127/3001) ...
# Generating image for seed 1128 (1128/3001) ...
# Generating image for seed 1129 (1129/3001) ...
# Generating image for seed 1130 (1130/3001) ...
# Generating image for seed 1131 (1131/3001) ...
# Generating image for seed 1132 (1132/3001) ...
# Generating image for seed 1133 (1133/3001) ...
# Generating image for seed 1134 (1134/3001) ...
# Generating image for seed 1135 (1135/3001) ...
# Generating image for seed 1136 (1136/3001) ...
# Generating image for seed 1137 (1137/3001) ...
# Generating image for seed 1138 (1138/3001) ...
# Generating image for seed 1139 (1139/3001) ...
# Generating image for seed 1140 (1140/3001) ...
# Generating image for seed 1141 (1141/3001) ...
# Generating image for seed 1142 (1142/3001) ...
# Generating image for seed 1143 (1143/3001) ...
# Generating image for seed 1144 (1144/3001) ...
# Generating image for seed 1145 (1145/3001) ...
# Generating image for seed 1146 (1146/3001) ...
# Generating image for seed 1147 (1147/3001) ...
# Generating image for seed 1148 (1148/3001) ...
# Generating image for seed 1149 (1149/3001) ...
# Generating image for seed 1150 (1150/3001) ...
# Generating image for seed 1151 (1151/3001) ...
# Generating image for seed 1152 (1152/3001) ...
# Generating image for seed 1153 (1153/3001) ...
# Generating image for seed 1154 (1154/3001) ...
# Generating image for seed 1155 (1155/3001) ...
# Generating image for seed 1156 (1156/3001) ...
# Generating image for seed 1157 (1157/3001) ...
# Generating image for seed 1158 (1158/3001) ...
# Generating image for seed 1159 (1159/3001) ...
# Generating image for seed 1160 (1160/3001) ...
# Generating image for seed 1161 (1161/3001) ...
# Generating image for seed 1162 (1162/3001) ...
# Generating image for seed 1163 (1163/3001) ...
# Generating image for seed 1164 (1164/3001) ...
# Generating image for seed 1165 (1165/3001) ...
# Generating image for seed 1166 (1166/3001) ...
# Generating image for seed 1167 (1167/3001) ...
# Generating image for seed 1168 (1168/3001) ...
# Generating image for seed 1169 (1169/3001) ...
# Generating image for seed 1170 (1170/3001) ...
# Generating image for seed 1171 (1171/3001) ...
# Generating image for seed 1172 (1172/3001) ...
# Generating image for seed 1173 (1173/3001) ...
# Generating image for seed 1174 (1174/3001) ...
# Generating image for seed 1175 (1175/3001) ...
# Generating image for seed 1176 (1176/3001) ...
# Generating image for seed 1177 (1177/3001) ...
# Generating image for seed 1178 (1178/3001) ...
# Generating image for seed 1179 (1179/3001) ...
# Generating image for seed 1180 (1180/3001) ...
# Generating image for seed 1181 (1181/3001) ...
# Generating image for seed 1182 (1182/3001) ...
# Generating image for seed 1183 (1183/3001) ...
# Generating image for seed 1184 (1184/3001) ...
# Generating image for seed 1185 (1185/3001) ...
# Generating image for seed 1186 (1186/3001) ...
# Generating image for seed 1187 (1187/3001) ...
# Generating image for seed 1188 (1188/3001) ...
# Generating image for seed 1189 (1189/3001) ...
# Generating image for seed 1190 (1190/3001) ...
# Generating image for seed 1191 (1191/3001) ...
# Generating image for seed 1192 (1192/3001) ...
# Generating image for seed 1193 (1193/3001) ...
# Generating image for seed 1194 (1194/3001) ...
# Generating image for seed 1195 (1195/3001) ...
# Generating image for seed 1196 (1196/3001) ...
# Generating image for seed 1197 (1197/3001) ...
# Generating image for seed 1198 (1198/3001) ...
# Generating image for seed 1199 (1199/3001) ...
# Generating image for seed 1200 (1200/3001) ...
# Generating image for seed 1201 (1201/3001) ...
# Generating image for seed 1202 (1202/3001) ...
# Generating image for seed 1203 (1203/3001) ...
# Generating image for seed 1204 (1204/3001) ...
# Generating image for seed 1205 (1205/3001) ...
# Generating image for seed 1206 (1206/3001) ...
# Generating image for seed 1207 (1207/3001) ...
# Generating image for seed 1208 (1208/3001) ...
# Generating image for seed 1209 (1209/3001) ...
# Generating image for seed 1210 (1210/3001) ...
# Generating image for seed 1211 (1211/3001) ...
# Generating image for seed 1212 (1212/3001) ...
# Generating image for seed 1213 (1213/3001) ...
# Generating image for seed 1214 (1214/3001) ...
# Generating image for seed 1215 (1215/3001) ...
# Generating image for seed 1216 (1216/3001) ...
# Generating image for seed 1217 (1217/3001) ...
# Generating image for seed 1218 (1218/3001) ...
# Generating image for seed 1219 (1219/3001) ...
# Generating image for seed 1220 (1220/3001) ...
# Generating image for seed 1221 (1221/3001) ...
# Generating image for seed 1222 (1222/3001) ...
# Generating image for seed 1223 (1223/3001) ...
# Generating image for seed 1224 (1224/3001) ...
# Generating image for seed 1225 (1225/3001) ...
# Generating image for seed 1226 (1226/3001) ...
# Generating image for seed 1227 (1227/3001) ...
# Generating image for seed 1228 (1228/3001) ...
# Generating image for seed 1229 (1229/3001) ...
# Generating image for seed 1230 (1230/3001) ...
# Generating image for seed 1231 (1231/3001) ...
# Generating image for seed 1232 (1232/3001) ...
# Generating image for seed 1233 (1233/3001) ...
# Generating image for seed 1234 (1234/3001) ...
# Generating image for seed 1235 (1235/3001) ...
# Generating image for seed 1236 (1236/3001) ...
# Generating image for seed 1237 (1237/3001) ...
# Generating image for seed 1238 (1238/3001) ...
# Generating image for seed 1239 (1239/3001) ...
# Generating image for seed 1240 (1240/3001) ...
# Generating image for seed 1241 (1241/3001) ...
# Generating image for seed 1242 (1242/3001) ...
# Generating image for seed 1243 (1243/3001) ...
# Generating image for seed 1244 (1244/3001) ...
# Generating image for seed 1245 (1245/3001) ...
# Generating image for seed 1246 (1246/3001) ...
# Generating image for seed 1247 (1247/3001) ...
# Generating image for seed 1248 (1248/3001) ...
# Generating image for seed 1249 (1249/3001) ...
# Generating image for seed 1250 (1250/3001) ...
# Generating image for seed 1251 (1251/3001) ...
# Generating image for seed 1252 (1252/3001) ...
# Generating image for seed 1253 (1253/3001) ...
# Generating image for seed 1254 (1254/3001) ...
# Generating image for seed 1255 (1255/3001) ...
# Generating image for seed 1256 (1256/3001) ...
# Generating image for seed 1257 (1257/3001) ...
# Generating image for seed 1258 (1258/3001) ...
# Generating image for seed 1259 (1259/3001) ...
# Generating image for seed 1260 (1260/3001) ...
# Generating image for seed 1261 (1261/3001) ...
# Generating image for seed 1262 (1262/3001) ...
# Generating image for seed 1263 (1263/3001) ...
# Generating image for seed 1264 (1264/3001) ...
# Generating image for seed 1265 (1265/3001) ...
# Generating image for seed 1266 (1266/3001) ...
# Generating image for seed 1267 (1267/3001) ...
# Generating image for seed 1268 (1268/3001) ...
# Generating image for seed 1269 (1269/3001) ...
# Generating image for seed 1270 (1270/3001) ...
# Generating image for seed 1271 (1271/3001) ...
# Generating image for seed 1272 (1272/3001) ...
# Generating image for seed 1273 (1273/3001) ...
# Generating image for seed 1274 (1274/3001) ...
# Generating image for seed 1275 (1275/3001) ...
# Generating image for seed 1276 (1276/3001) ...
# Generating image for seed 1277 (1277/3001) ...
# Generating image for seed 1278 (1278/3001) ...
# Generating image for seed 1279 (1279/3001) ...
# Generating image for seed 1280 (1280/3001) ...
# Generating image for seed 1281 (1281/3001) ...
# Generating image for seed 1282 (1282/3001) ...
# Generating image for seed 1283 (1283/3001) ...
# Generating image for seed 1284 (1284/3001) ...
# Generating image for seed 1285 (1285/3001) ...
# Generating image for seed 1286 (1286/3001) ...
# Generating image for seed 1287 (1287/3001) ...
# Generating image for seed 1288 (1288/3001) ...
# Generating image for seed 1289 (1289/3001) ...
# Generating image for seed 1290 (1290/3001) ...
# Generating image for seed 1291 (1291/3001) ...
# Generating image for seed 1292 (1292/3001) ...
# Generating image for seed 1293 (1293/3001) ...
# Generating image for seed 1294 (1294/3001) ...
# Generating image for seed 1295 (1295/3001) ...
# Generating image for seed 1296 (1296/3001) ...
# Generating image for seed 1297 (1297/3001) ...
# Generating image for seed 1298 (1298/3001) ...
# Generating image for seed 1299 (1299/3001) ...
# Generating image for seed 1300 (1300/3001) ...
# Generating image for seed 1301 (1301/3001) ...
# Generating image for seed 1302 (1302/3001) ...
# Generating image for seed 1303 (1303/3001) ...
# Generating image for seed 1304 (1304/3001) ...
# Generating image for seed 1305 (1305/3001) ...
# Generating image for seed 1306 (1306/3001) ...
# Generating image for seed 1307 (1307/3001) ...
# Generating image for seed 1308 (1308/3001) ...
# Generating image for seed 1309 (1309/3001) ...
# Generating image for seed 1310 (1310/3001) ...
# Generating image for seed 1311 (1311/3001) ...
# Generating image for seed 1312 (1312/3001) ...
# Generating image for seed 1313 (1313/3001) ...
# Generating image for seed 1314 (1314/3001) ...
# Generating image for seed 1315 (1315/3001) ...
# Generating image for seed 1316 (1316/3001) ...
# Generating image for seed 1317 (1317/3001) ...
# Generating image for seed 1318 (1318/3001) ...
# Generating image for seed 1319 (1319/3001) ...
# Generating image for seed 1320 (1320/3001) ...
# Generating image for seed 1321 (1321/3001) ...
# Generating image for seed 1322 (1322/3001) ...
# Generating image for seed 1323 (1323/3001) ...
# Generating image for seed 1324 (1324/3001) ...
# Generating image for seed 1325 (1325/3001) ...
# Generating image for seed 1326 (1326/3001) ...
# Generating image for seed 1327 (1327/3001) ...
# Generating image for seed 1328 (1328/3001) ...
# Generating image for seed 1329 (1329/3001) ...
# Generating image for seed 1330 (1330/3001) ...
# Generating image for seed 1331 (1331/3001) ...
# Generating image for seed 1332 (1332/3001) ...
# Generating image for seed 1333 (1333/3001) ...
# Generating image for seed 1334 (1334/3001) ...
# Generating image for seed 1335 (1335/3001) ...
# Generating image for seed 1336 (1336/3001) ...
# Generating image for seed 1337 (1337/3001) ...
# Generating image for seed 1338 (1338/3001) ...
# Generating image for seed 1339 (1339/3001) ...
# Generating image for seed 1340 (1340/3001) ...
# Generating image for seed 1341 (1341/3001) ...
# Generating image for seed 1342 (1342/3001) ...
# Generating image for seed 1343 (1343/3001) ...
# Generating image for seed 1344 (1344/3001) ...
# Generating image for seed 1345 (1345/3001) ...
# Generating image for seed 1346 (1346/3001) ...
# Generating image for seed 1347 (1347/3001) ...
# Generating image for seed 1348 (1348/3001) ...
# Generating image for seed 1349 (1349/3001) ...
# Generating image for seed 1350 (1350/3001) ...
# Generating image for seed 1351 (1351/3001) ...
# Generating image for seed 1352 (1352/3001) ...
# Generating image for seed 1353 (1353/3001) ...
# Generating image for seed 1354 (1354/3001) ...
# Generating image for seed 1355 (1355/3001) ...
# Generating image for seed 1356 (1356/3001) ...
# Generating image for seed 1357 (1357/3001) ...
# Generating image for seed 1358 (1358/3001) ...
# Generating image for seed 1359 (1359/3001) ...
# Generating image for seed 1360 (1360/3001) ...
# Generating image for seed 1361 (1361/3001) ...
# Generating image for seed 1362 (1362/3001) ...
# Generating image for seed 1363 (1363/3001) ...
# Generating image for seed 1364 (1364/3001) ...
# Generating image for seed 1365 (1365/3001) ...
# Generating image for seed 1366 (1366/3001) ...
# Generating image for seed 1367 (1367/3001) ...
# Generating image for seed 1368 (1368/3001) ...
# Generating image for seed 1369 (1369/3001) ...
# Generating image for seed 1370 (1370/3001) ...
# Generating image for seed 1371 (1371/3001) ...
# Generating image for seed 1372 (1372/3001) ...
# Generating image for seed 1373 (1373/3001) ...
# Generating image for seed 1374 (1374/3001) ...
# Generating image for seed 1375 (1375/3001) ...
# Generating image for seed 1376 (1376/3001) ...
# Generating image for seed 1377 (1377/3001) ...
# Generating image for seed 1378 (1378/3001) ...
# Generating image for seed 1379 (1379/3001) ...
# Generating image for seed 1380 (1380/3001) ...
# Generating image for seed 1381 (1381/3001) ...
# Generating image for seed 1382 (1382/3001) ...
# Generating image for seed 1383 (1383/3001) ...
# Generating image for seed 1384 (1384/3001) ...
# Generating image for seed 1385 (1385/3001) ...
# Generating image for seed 1386 (1386/3001) ...
# Generating image for seed 1387 (1387/3001) ...
# Generating image for seed 1388 (1388/3001) ...
# Generating image for seed 1389 (1389/3001) ...
# Generating image for seed 1390 (1390/3001) ...
# Generating image for seed 1391 (1391/3001) ...
# Generating image for seed 1392 (1392/3001) ...
# Generating image for seed 1393 (1393/3001) ...
# Generating image for seed 1394 (1394/3001) ...
# Generating image for seed 1395 (1395/3001) ...
# Generating image for seed 1396 (1396/3001) ...
# Generating image for seed 1397 (1397/3001) ...
# Generating image for seed 1398 (1398/3001) ...
# Generating image for seed 1399 (1399/3001) ...
# Generating image for seed 1400 (1400/3001) ...
# Generating image for seed 1401 (1401/3001) ...
# Generating image for seed 1402 (1402/3001) ...
# Generating image for seed 1403 (1403/3001) ...
# Generating image for seed 1404 (1404/3001) ...
# Generating image for seed 1405 (1405/3001) ...
# Generating image for seed 1406 (1406/3001) ...
# Generating image for seed 1407 (1407/3001) ...
# Generating image for seed 1408 (1408/3001) ...
# Generating image for seed 1409 (1409/3001) ...
# Generating image for seed 1410 (1410/3001) ...
# Generating image for seed 1411 (1411/3001) ...
# Generating image for seed 1412 (1412/3001) ...
# Generating image for seed 1413 (1413/3001) ...
# Generating image for seed 1414 (1414/3001) ...
# Generating image for seed 1415 (1415/3001) ...
# Generating image for seed 1416 (1416/3001) ...
# Generating image for seed 1417 (1417/3001) ...
# Generating image for seed 1418 (1418/3001) ...
# Generating image for seed 1419 (1419/3001) ...
# Generating image for seed 1420 (1420/3001) ...
# Generating image for seed 1421 (1421/3001) ...
# Generating image for seed 1422 (1422/3001) ...
# Generating image for seed 1423 (1423/3001) ...
# Generating image for seed 1424 (1424/3001) ...
# Generating image for seed 1425 (1425/3001) ...
# Generating image for seed 1426 (1426/3001) ...
# Generating image for seed 1427 (1427/3001) ...
# Generating image for seed 1428 (1428/3001) ...
# Generating image for seed 1429 (1429/3001) ...
# Generating image for seed 1430 (1430/3001) ...
# Generating image for seed 1431 (1431/3001) ...
# Generating image for seed 1432 (1432/3001) ...
# Generating image for seed 1433 (1433/3001) ...
# Generating image for seed 1434 (1434/3001) ...
# Generating image for seed 1435 (1435/3001) ...
# Generating image for seed 1436 (1436/3001) ...
# Generating image for seed 1437 (1437/3001) ...
# Generating image for seed 1438 (1438/3001) ...
# Generating image for seed 1439 (1439/3001) ...
# Generating image for seed 1440 (1440/3001) ...
# Generating image for seed 1441 (1441/3001) ...
# Generating image for seed 1442 (1442/3001) ...
# Generating image for seed 1443 (1443/3001) ...
# Generating image for seed 1444 (1444/3001) ...
# Generating image for seed 1445 (1445/3001) ...
# Generating image for seed 1446 (1446/3001) ...
# Generating image for seed 1447 (1447/3001) ...
# Generating image for seed 1448 (1448/3001) ...
# Generating image for seed 1449 (1449/3001) ...
# Generating image for seed 1450 (1450/3001) ...
# Generating image for seed 1451 (1451/3001) ...
# Generating image for seed 1452 (1452/3001) ...
# Generating image for seed 1453 (1453/3001) ...
# Generating image for seed 1454 (1454/3001) ...
# Generating image for seed 1455 (1455/3001) ...
# Generating image for seed 1456 (1456/3001) ...
# Generating image for seed 1457 (1457/3001) ...
# Generating image for seed 1458 (1458/3001) ...
# Generating image for seed 1459 (1459/3001) ...
# Generating image for seed 1460 (1460/3001) ...
# Generating image for seed 1461 (1461/3001) ...
# Generating image for seed 1462 (1462/3001) ...
# Generating image for seed 1463 (1463/3001) ...
# Generating image for seed 1464 (1464/3001) ...
# Generating image for seed 1465 (1465/3001) ...
# Generating image for seed 1466 (1466/3001) ...
# Generating image for seed 1467 (1467/3001) ...
# Generating image for seed 1468 (1468/3001) ...
# Generating image for seed 1469 (1469/3001) ...
# Generating image for seed 1470 (1470/3001) ...
# Generating image for seed 1471 (1471/3001) ...
# Generating image for seed 1472 (1472/3001) ...
# Generating image for seed 1473 (1473/3001) ...
# Generating image for seed 1474 (1474/3001) ...
# Generating image for seed 1475 (1475/3001) ...
# Generating image for seed 1476 (1476/3001) ...
# Generating image for seed 1477 (1477/3001) ...
# Generating image for seed 1478 (1478/3001) ...
# Generating image for seed 1479 (1479/3001) ...
# Generating image for seed 1480 (1480/3001) ...
# Generating image for seed 1481 (1481/3001) ...
# Generating image for seed 1482 (1482/3001) ...
# Generating image for seed 1483 (1483/3001) ...
# Generating image for seed 1484 (1484/3001) ...
# Generating image for seed 1485 (1485/3001) ...
# Generating image for seed 1486 (1486/3001) ...
# Generating image for seed 1487 (1487/3001) ...
# Generating image for seed 1488 (1488/3001) ...
# Generating image for seed 1489 (1489/3001) ...
# Generating image for seed 1490 (1490/3001) ...
# Generating image for seed 1491 (1491/3001) ...
# Generating image for seed 1492 (1492/3001) ...
# Generating image for seed 1493 (1493/3001) ...
# Generating image for seed 1494 (1494/3001) ...
# Generating image for seed 1495 (1495/3001) ...
# Generating image for seed 1496 (1496/3001) ...
# Generating image for seed 1497 (1497/3001) ...
# Generating image for seed 1498 (1498/3001) ...
# Generating image for seed 1499 (1499/3001) ...
# Generating image for seed 1500 (1500/3001) ...
# Generating image for seed 1501 (1501/3001) ...
# Generating image for seed 1502 (1502/3001) ...
# Generating image for seed 1503 (1503/3001) ...
# Generating image for seed 1504 (1504/3001) ...
# Generating image for seed 1505 (1505/3001) ...
# Generating image for seed 1506 (1506/3001) ...
# Generating image for seed 1507 (1507/3001) ...
# Generating image for seed 1508 (1508/3001) ...
# Generating image for seed 1509 (1509/3001) ...
# Generating image for seed 1510 (1510/3001) ...
# Generating image for seed 1511 (1511/3001) ...
# Generating image for seed 1512 (1512/3001) ...
# Generating image for seed 1513 (1513/3001) ...
# Generating image for seed 1514 (1514/3001) ...
# Generating image for seed 1515 (1515/3001) ...
# Generating image for seed 1516 (1516/3001) ...
# Generating image for seed 1517 (1517/3001) ...
# Generating image for seed 1518 (1518/3001) ...
# Generating image for seed 1519 (1519/3001) ...
# Generating image for seed 1520 (1520/3001) ...
# Generating image for seed 1521 (1521/3001) ...
# Generating image for seed 1522 (1522/3001) ...
# Generating image for seed 1523 (1523/3001) ...
# Generating image for seed 1524 (1524/3001) ...
# Generating image for seed 1525 (1525/3001) ...
# Generating image for seed 1526 (1526/3001) ...
# Generating image for seed 1527 (1527/3001) ...
# Generating image for seed 1528 (1528/3001) ...
# Generating image for seed 1529 (1529/3001) ...
# Generating image for seed 1530 (1530/3001) ...
# Generating image for seed 1531 (1531/3001) ...
# Generating image for seed 1532 (1532/3001) ...
# Generating image for seed 1533 (1533/3001) ...
# Generating image for seed 1534 (1534/3001) ...
# Generating image for seed 1535 (1535/3001) ...
# Generating image for seed 1536 (1536/3001) ...
# Generating image for seed 1537 (1537/3001) ...
# Generating image for seed 1538 (1538/3001) ...
# Generating image for seed 1539 (1539/3001) ...
# Generating image for seed 1540 (1540/3001) ...
# Generating image for seed 1541 (1541/3001) ...
# Generating image for seed 1542 (1542/3001) ...
# Generating image for seed 1543 (1543/3001) ...
# Generating image for seed 1544 (1544/3001) ...
# Generating image for seed 1545 (1545/3001) ...
# Generating image for seed 1546 (1546/3001) ...
# Generating image for seed 1547 (1547/3001) ...
# Generating image for seed 1548 (1548/3001) ...
# Generating image for seed 1549 (1549/3001) ...
# Generating image for seed 1550 (1550/3001) ...
# Generating image for seed 1551 (1551/3001) ...
# Generating image for seed 1552 (1552/3001) ...
# Generating image for seed 1553 (1553/3001) ...
# Generating image for seed 1554 (1554/3001) ...
# Generating image for seed 1555 (1555/3001) ...
# Generating image for seed 1556 (1556/3001) ...
# Generating image for seed 1557 (1557/3001) ...
# Generating image for seed 1558 (1558/3001) ...
# Generating image for seed 1559 (1559/3001) ...
# Generating image for seed 1560 (1560/3001) ...
# Generating image for seed 1561 (1561/3001) ...
# Generating image for seed 1562 (1562/3001) ...
# Generating image for seed 1563 (1563/3001) ...
# Generating image for seed 1564 (1564/3001) ...
# Generating image for seed 1565 (1565/3001) ...
# Generating image for seed 1566 (1566/3001) ...
# Generating image for seed 1567 (1567/3001) ...
# Generating image for seed 1568 (1568/3001) ...
# Generating image for seed 1569 (1569/3001) ...
# Generating image for seed 1570 (1570/3001) ...
# Generating image for seed 1571 (1571/3001) ...
# Generating image for seed 1572 (1572/3001) ...
# Generating image for seed 1573 (1573/3001) ...
# Generating image for seed 1574 (1574/3001) ...
# Generating image for seed 1575 (1575/3001) ...
# Generating image for seed 1576 (1576/3001) ...
# Generating image for seed 1577 (1577/3001) ...
# Generating image for seed 1578 (1578/3001) ...
# Generating image for seed 1579 (1579/3001) ...
# Generating image for seed 1580 (1580/3001) ...
# Generating image for seed 1581 (1581/3001) ...
# Generating image for seed 1582 (1582/3001) ...
# Generating image for seed 1583 (1583/3001) ...
# Generating image for seed 1584 (1584/3001) ...
# Generating image for seed 1585 (1585/3001) ...
# Generating image for seed 1586 (1586/3001) ...
# Generating image for seed 1587 (1587/3001) ...
# Generating image for seed 1588 (1588/3001) ...
# Generating image for seed 1589 (1589/3001) ...
# Generating image for seed 1590 (1590/3001) ...
# Generating image for seed 1591 (1591/3001) ...
# Generating image for seed 1592 (1592/3001) ...
# Generating image for seed 1593 (1593/3001) ...
# Generating image for seed 1594 (1594/3001) ...
# Generating image for seed 1595 (1595/3001) ...
# Generating image for seed 1596 (1596/3001) ...
# Generating image for seed 1597 (1597/3001) ...
# Generating image for seed 1598 (1598/3001) ...
# Generating image for seed 1599 (1599/3001) ...
# Generating image for seed 1600 (1600/3001) ...
# Generating image for seed 1601 (1601/3001) ...
# Generating image for seed 1602 (1602/3001) ...
# Generating image for seed 1603 (1603/3001) ...
# Generating image for seed 1604 (1604/3001) ...
# Generating image for seed 1605 (1605/3001) ...
# Generating image for seed 1606 (1606/3001) ...
# Generating image for seed 1607 (1607/3001) ...
# Generating image for seed 1608 (1608/3001) ...
# Generating image for seed 1609 (1609/3001) ...
# Generating image for seed 1610 (1610/3001) ...
# Generating image for seed 1611 (1611/3001) ...
# Generating image for seed 1612 (1612/3001) ...
# Generating image for seed 1613 (1613/3001) ...
# Generating image for seed 1614 (1614/3001) ...
# Generating image for seed 1615 (1615/3001) ...
# Generating image for seed 1616 (1616/3001) ...
# Generating image for seed 1617 (1617/3001) ...
# Generating image for seed 1618 (1618/3001) ...
# Generating image for seed 1619 (1619/3001) ...
# Generating image for seed 1620 (1620/3001) ...
# Generating image for seed 1621 (1621/3001) ...
# Generating image for seed 1622 (1622/3001) ...
# Generating image for seed 1623 (1623/3001) ...
# Generating image for seed 1624 (1624/3001) ...
# Generating image for seed 1625 (1625/3001) ...
# Generating image for seed 1626 (1626/3001) ...
# Generating image for seed 1627 (1627/3001) ...
# Generating image for seed 1628 (1628/3001) ...
# Generating image for seed 1629 (1629/3001) ...
# Generating image for seed 1630 (1630/3001) ...
# Generating image for seed 1631 (1631/3001) ...
# Generating image for seed 1632 (1632/3001) ...
# Generating image for seed 1633 (1633/3001) ...
# Generating image for seed 1634 (1634/3001) ...
# Generating image for seed 1635 (1635/3001) ...
# Generating image for seed 1636 (1636/3001) ...
# Generating image for seed 1637 (1637/3001) ...
# Generating image for seed 1638 (1638/3001) ...
# Generating image for seed 1639 (1639/3001) ...
# Generating image for seed 1640 (1640/3001) ...
# Generating image for seed 1641 (1641/3001) ...
# Generating image for seed 1642 (1642/3001) ...
# Generating image for seed 1643 (1643/3001) ...
# Generating image for seed 1644 (1644/3001) ...
# Generating image for seed 1645 (1645/3001) ...
# Generating image for seed 1646 (1646/3001) ...
# Generating image for seed 1647 (1647/3001) ...
# Generating image for seed 1648 (1648/3001) ...
# Generating image for seed 1649 (1649/3001) ...
# Generating image for seed 1650 (1650/3001) ...
# Generating image for seed 1651 (1651/3001) ...
# Generating image for seed 1652 (1652/3001) ...
# Generating image for seed 1653 (1653/3001) ...
# Generating image for seed 1654 (1654/3001) ...
# Generating image for seed 1655 (1655/3001) ...
# Generating image for seed 1656 (1656/3001) ...
# Generating image for seed 1657 (1657/3001) ...
# Generating image for seed 1658 (1658/3001) ...
# Generating image for seed 1659 (1659/3001) ...
# Generating image for seed 1660 (1660/3001) ...
# Generating image for seed 1661 (1661/3001) ...
# Generating image for seed 1662 (1662/3001) ...
# Generating image for seed 1663 (1663/3001) ...
# Generating image for seed 1664 (1664/3001) ...
# Generating image for seed 1665 (1665/3001) ...
# Generating image for seed 1666 (1666/3001) ...
# Generating image for seed 1667 (1667/3001) ...
# Generating image for seed 1668 (1668/3001) ...
# Generating image for seed 1669 (1669/3001) ...
# Generating image for seed 1670 (1670/3001) ...
# Generating image for seed 1671 (1671/3001) ...
# Generating image for seed 1672 (1672/3001) ...
# Generating image for seed 1673 (1673/3001) ...
# Generating image for seed 1674 (1674/3001) ...
# Generating image for seed 1675 (1675/3001) ...
# Generating image for seed 1676 (1676/3001) ...
# Generating image for seed 1677 (1677/3001) ...
# Generating image for seed 1678 (1678/3001) ...
# Generating image for seed 1679 (1679/3001) ...
# Generating image for seed 1680 (1680/3001) ...
# Generating image for seed 1681 (1681/3001) ...
# Generating image for seed 1682 (1682/3001) ...
# Generating image for seed 1683 (1683/3001) ...
# Generating image for seed 1684 (1684/3001) ...
# Generating image for seed 1685 (1685/3001) ...
# Generating image for seed 1686 (1686/3001) ...
# Generating image for seed 1687 (1687/3001) ...
# Generating image for seed 1688 (1688/3001) ...
# Generating image for seed 1689 (1689/3001) ...
# Generating image for seed 1690 (1690/3001) ...
# Generating image for seed 1691 (1691/3001) ...
# Generating image for seed 1692 (1692/3001) ...
# Generating image for seed 1693 (1693/3001) ...
# Generating image for seed 1694 (1694/3001) ...
# Generating image for seed 1695 (1695/3001) ...
# Generating image for seed 1696 (1696/3001) ...
# Generating image for seed 1697 (1697/3001) ...
# Generating image for seed 1698 (1698/3001) ...
# Generating image for seed 1699 (1699/3001) ...
# Generating image for seed 1700 (1700/3001) ...
# Generating image for seed 1701 (1701/3001) ...
# Generating image for seed 1702 (1702/3001) ...
# Generating image for seed 1703 (1703/3001) ...
# Generating image for seed 1704 (1704/3001) ...
# Generating image for seed 1705 (1705/3001) ...
# Generating image for seed 1706 (1706/3001) ...
# Generating image for seed 1707 (1707/3001) ...
# Generating image for seed 1708 (1708/3001) ...
# Generating image for seed 1709 (1709/3001) ...
# Generating image for seed 1710 (1710/3001) ...
# Generating image for seed 1711 (1711/3001) ...
# Generating image for seed 1712 (1712/3001) ...
# Generating image for seed 1713 (1713/3001) ...
# Generating image for seed 1714 (1714/3001) ...
# Generating image for seed 1715 (1715/3001) ...
# Generating image for seed 1716 (1716/3001) ...
# Generating image for seed 1717 (1717/3001) ...
# Generating image for seed 1718 (1718/3001) ...
# Generating image for seed 1719 (1719/3001) ...
# Generating image for seed 1720 (1720/3001) ...
# Generating image for seed 1721 (1721/3001) ...
# Generating image for seed 1722 (1722/3001) ...
# Generating image for seed 1723 (1723/3001) ...
# Generating image for seed 1724 (1724/3001) ...
# Generating image for seed 1725 (1725/3001) ...
# Generating image for seed 1726 (1726/3001) ...
# Generating image for seed 1727 (1727/3001) ...
# Generating image for seed 1728 (1728/3001) ...
# Generating image for seed 1729 (1729/3001) ...
# Generating image for seed 1730 (1730/3001) ...
# Generating image for seed 1731 (1731/3001) ...
# Generating image for seed 1732 (1732/3001) ...
# Generating image for seed 1733 (1733/3001) ...
# Generating image for seed 1734 (1734/3001) ...
# Generating image for seed 1735 (1735/3001) ...
# Generating image for seed 1736 (1736/3001) ...
# Generating image for seed 1737 (1737/3001) ...
# Generating image for seed 1738 (1738/3001) ...
# Generating image for seed 1739 (1739/3001) ...
# Generating image for seed 1740 (1740/3001) ...
# Generating image for seed 1741 (1741/3001) ...
# Generating image for seed 1742 (1742/3001) ...
# Generating image for seed 1743 (1743/3001) ...
# Generating image for seed 1744 (1744/3001) ...
# Generating image for seed 1745 (1745/3001) ...
# Generating image for seed 1746 (1746/3001) ...
# Generating image for seed 1747 (1747/3001) ...
# Generating image for seed 1748 (1748/3001) ...
# Generating image for seed 1749 (1749/3001) ...
# Generating image for seed 1750 (1750/3001) ...
# Generating image for seed 1751 (1751/3001) ...
# Generating image for seed 1752 (1752/3001) ...
# Generating image for seed 1753 (1753/3001) ...
# Generating image for seed 1754 (1754/3001) ...
# Generating image for seed 1755 (1755/3001) ...
# Generating image for seed 1756 (1756/3001) ...
# Generating image for seed 1757 (1757/3001) ...
# Generating image for seed 1758 (1758/3001) ...
# Generating image for seed 1759 (1759/3001) ...
# Generating image for seed 1760 (1760/3001) ...
# Generating image for seed 1761 (1761/3001) ...
# Generating image for seed 1762 (1762/3001) ...
# Generating image for seed 1763 (1763/3001) ...
# Generating image for seed 1764 (1764/3001) ...
# Generating image for seed 1765 (1765/3001) ...
# Generating image for seed 1766 (1766/3001) ...
# Generating image for seed 1767 (1767/3001) ...
# Generating image for seed 1768 (1768/3001) ...
# Generating image for seed 1769 (1769/3001) ...
# Generating image for seed 1770 (1770/3001) ...
# Generating image for seed 1771 (1771/3001) ...
# Generating image for seed 1772 (1772/3001) ...
# Generating image for seed 1773 (1773/3001) ...
# Generating image for seed 1774 (1774/3001) ...
# Generating image for seed 1775 (1775/3001) ...
# Generating image for seed 1776 (1776/3001) ...
# Generating image for seed 1777 (1777/3001) ...
# Generating image for seed 1778 (1778/3001) ...
# Generating image for seed 1779 (1779/3001) ...
# Generating image for seed 1780 (1780/3001) ...
# Generating image for seed 1781 (1781/3001) ...
# Generating image for seed 1782 (1782/3001) ...
# Generating image for seed 1783 (1783/3001) ...
# Generating image for seed 1784 (1784/3001) ...
# Generating image for seed 1785 (1785/3001) ...
# Generating image for seed 1786 (1786/3001) ...
# Generating image for seed 1787 (1787/3001) ...
# Generating image for seed 1788 (1788/3001) ...
# Generating image for seed 1789 (1789/3001) ...
# Generating image for seed 1790 (1790/3001) ...
# Generating image for seed 1791 (1791/3001) ...
# Generating image for seed 1792 (1792/3001) ...
# Generating image for seed 1793 (1793/3001) ...
# Generating image for seed 1794 (1794/3001) ...
# Generating image for seed 1795 (1795/3001) ...
# Generating image for seed 1796 (1796/3001) ...
# Generating image for seed 1797 (1797/3001) ...
# Generating image for seed 1798 (1798/3001) ...
# Generating image for seed 1799 (1799/3001) ...
# Generating image for seed 1800 (1800/3001) ...
# Generating image for seed 1801 (1801/3001) ...
# Generating image for seed 1802 (1802/3001) ...
# Generating image for seed 1803 (1803/3001) ...
# Generating image for seed 1804 (1804/3001) ...
# Generating image for seed 1805 (1805/3001) ...
# Generating image for seed 1806 (1806/3001) ...
# Generating image for seed 1807 (1807/3001) ...
# Generating image for seed 1808 (1808/3001) ...
# Generating image for seed 1809 (1809/3001) ...
# Generating image for seed 1810 (1810/3001) ...
# Generating image for seed 1811 (1811/3001) ...
# Generating image for seed 1812 (1812/3001) ...
# Generating image for seed 1813 (1813/3001) ...
# Generating image for seed 1814 (1814/3001) ...
# Generating image for seed 1815 (1815/3001) ...
# Generating image for seed 1816 (1816/3001) ...
# Generating image for seed 1817 (1817/3001) ...
# Generating image for seed 1818 (1818/3001) ...
# Generating image for seed 1819 (1819/3001) ...
# Generating image for seed 1820 (1820/3001) ...
# Generating image for seed 1821 (1821/3001) ...
# Generating image for seed 1822 (1822/3001) ...
# Generating image for seed 1823 (1823/3001) ...
# Generating image for seed 1824 (1824/3001) ...
# Generating image for seed 1825 (1825/3001) ...
# Generating image for seed 1826 (1826/3001) ...
# Generating image for seed 1827 (1827/3001) ...
# Generating image for seed 1828 (1828/3001) ...
# Generating image for seed 1829 (1829/3001) ...
# Generating image for seed 1830 (1830/3001) ...
# Generating image for seed 1831 (1831/3001) ...
# Generating image for seed 1832 (1832/3001) ...
# Generating image for seed 1833 (1833/3001) ...
# Generating image for seed 1834 (1834/3001) ...
# Generating image for seed 1835 (1835/3001) ...
# Generating image for seed 1836 (1836/3001) ...
# Generating image for seed 1837 (1837/3001) ...
# Generating image for seed 1838 (1838/3001) ...
# Generating image for seed 1839 (1839/3001) ...
# Generating image for seed 1840 (1840/3001) ...
# Generating image for seed 1841 (1841/3001) ...
# Generating image for seed 1842 (1842/3001) ...
# Generating image for seed 1843 (1843/3001) ...
# Generating image for seed 1844 (1844/3001) ...
# Generating image for seed 1845 (1845/3001) ...
# Generating image for seed 1846 (1846/3001) ...
# Generating image for seed 1847 (1847/3001) ...
# Generating image for seed 1848 (1848/3001) ...
# Generating image for seed 1849 (1849/3001) ...
# Generating image for seed 1850 (1850/3001) ...
# Generating image for seed 1851 (1851/3001) ...
# Generating image for seed 1852 (1852/3001) ...
# Generating image for seed 1853 (1853/3001) ...
# Generating image for seed 1854 (1854/3001) ...
# Generating image for seed 1855 (1855/3001) ...
# Generating image for seed 1856 (1856/3001) ...
# Generating image for seed 1857 (1857/3001) ...
# Generating image for seed 1858 (1858/3001) ...
# Generating image for seed 1859 (1859/3001) ...
# Generating image for seed 1860 (1860/3001) ...
# Generating image for seed 1861 (1861/3001) ...
# Generating image for seed 1862 (1862/3001) ...
# Generating image for seed 1863 (1863/3001) ...
# Generating image for seed 1864 (1864/3001) ...
# Generating image for seed 1865 (1865/3001) ...
# Generating image for seed 1866 (1866/3001) ...
# Generating image for seed 1867 (1867/3001) ...
# Generating image for seed 1868 (1868/3001) ...
# Generating image for seed 1869 (1869/3001) ...
# Generating image for seed 1870 (1870/3001) ...
# Generating image for seed 1871 (1871/3001) ...
# Generating image for seed 1872 (1872/3001) ...
# Generating image for seed 1873 (1873/3001) ...
# Generating image for seed 1874 (1874/3001) ...
# Generating image for seed 1875 (1875/3001) ...
# Generating image for seed 1876 (1876/3001) ...
# Generating image for seed 1877 (1877/3001) ...
# Generating image for seed 1878 (1878/3001) ...
# Generating image for seed 1879 (1879/3001) ...
# Generating image for seed 1880 (1880/3001) ...
# Generating image for seed 1881 (1881/3001) ...
# Generating image for seed 1882 (1882/3001) ...
# Generating image for seed 1883 (1883/3001) ...
# Generating image for seed 1884 (1884/3001) ...
# Generating image for seed 1885 (1885/3001) ...
# Generating image for seed 1886 (1886/3001) ...
# Generating image for seed 1887 (1887/3001) ...
# Generating image for seed 1888 (1888/3001) ...
# Generating image for seed 1889 (1889/3001) ...
# Generating image for seed 1890 (1890/3001) ...
# Generating image for seed 1891 (1891/3001) ...
# Generating image for seed 1892 (1892/3001) ...
# Generating image for seed 1893 (1893/3001) ...
# Generating image for seed 1894 (1894/3001) ...
# Generating image for seed 1895 (1895/3001) ...
# Generating image for seed 1896 (1896/3001) ...
# Generating image for seed 1897 (1897/3001) ...
# Generating image for seed 1898 (1898/3001) ...
# Generating image for seed 1899 (1899/3001) ...
# Generating image for seed 1900 (1900/3001) ...
# Generating image for seed 1901 (1901/3001) ...
# Generating image for seed 1902 (1902/3001) ...
# Generating image for seed 1903 (1903/3001) ...
# Generating image for seed 1904 (1904/3001) ...
# Generating image for seed 1905 (1905/3001) ...
# Generating image for seed 1906 (1906/3001) ...
# Generating image for seed 1907 (1907/3001) ...
# Generating image for seed 1908 (1908/3001) ...
# Generating image for seed 1909 (1909/3001) ...
# Generating image for seed 1910 (1910/3001) ...
# Generating image for seed 1911 (1911/3001) ...
# Generating image for seed 1912 (1912/3001) ...
# Generating image for seed 1913 (1913/3001) ...
# Generating image for seed 1914 (1914/3001) ...
# Generating image for seed 1915 (1915/3001) ...
# Generating image for seed 1916 (1916/3001) ...
# Generating image for seed 1917 (1917/3001) ...
# Generating image for seed 1918 (1918/3001) ...
# Generating image for seed 1919 (1919/3001) ...
# Generating image for seed 1920 (1920/3001) ...
# Generating image for seed 1921 (1921/3001) ...
# Generating image for seed 1922 (1922/3001) ...
# Generating image for seed 1923 (1923/3001) ...
# Generating image for seed 1924 (1924/3001) ...
# Generating image for seed 1925 (1925/3001) ...
# Generating image for seed 1926 (1926/3001) ...
# Generating image for seed 1927 (1927/3001) ...
# Generating image for seed 1928 (1928/3001) ...
# Generating image for seed 1929 (1929/3001) ...
# Generating image for seed 1930 (1930/3001) ...
# Generating image for seed 1931 (1931/3001) ...
# Generating image for seed 1932 (1932/3001) ...
# Generating image for seed 1933 (1933/3001) ...
# Generating image for seed 1934 (1934/3001) ...
# Generating image for seed 1935 (1935/3001) ...
# Generating image for seed 1936 (1936/3001) ...
# Generating image for seed 1937 (1937/3001) ...
# Generating image for seed 1938 (1938/3001) ...
# Generating image for seed 1939 (1939/3001) ...
# Generating image for seed 1940 (1940/3001) ...
# Generating image for seed 1941 (1941/3001) ...
# Generating image for seed 1942 (1942/3001) ...
# Generating image for seed 1943 (1943/3001) ...
# Generating image for seed 1944 (1944/3001) ...
# Generating image for seed 1945 (1945/3001) ...
# Generating image for seed 1946 (1946/3001) ...
# Generating image for seed 1947 (1947/3001) ...
# Generating image for seed 1948 (1948/3001) ...
# Generating image for seed 1949 (1949/3001) ...
# Generating image for seed 1950 (1950/3001) ...
# Generating image for seed 1951 (1951/3001) ...
# Generating image for seed 1952 (1952/3001) ...
# Generating image for seed 1953 (1953/3001) ...
# Generating image for seed 1954 (1954/3001) ...
# Generating image for seed 1955 (1955/3001) ...
# Generating image for seed 1956 (1956/3001) ...
# Generating image for seed 1957 (1957/3001) ...
# Generating image for seed 1958 (1958/3001) ...
# Generating image for seed 1959 (1959/3001) ...
# Generating image for seed 1960 (1960/3001) ...
# Generating image for seed 1961 (1961/3001) ...
# Generating image for seed 1962 (1962/3001) ...
# Generating image for seed 1963 (1963/3001) ...
# Generating image for seed 1964 (1964/3001) ...
# Generating image for seed 1965 (1965/3001) ...
# Generating image for seed 1966 (1966/3001) ...
# Generating image for seed 1967 (1967/3001) ...
# Generating image for seed 1968 (1968/3001) ...
# Generating image for seed 1969 (1969/3001) ...
# Generating image for seed 1970 (1970/3001) ...
# Generating image for seed 1971 (1971/3001) ...
# Generating image for seed 1972 (1972/3001) ...
# Generating image for seed 1973 (1973/3001) ...
# Generating image for seed 1974 (1974/3001) ...
# Generating image for seed 1975 (1975/3001) ...
# Generating image for seed 1976 (1976/3001) ...
# Generating image for seed 1977 (1977/3001) ...
# Generating image for seed 1978 (1978/3001) ...
# Generating image for seed 1979 (1979/3001) ...
# Generating image for seed 1980 (1980/3001) ...
# Generating image for seed 1981 (1981/3001) ...
# Generating image for seed 1982 (1982/3001) ...
# Generating image for seed 1983 (1983/3001) ...
# Generating image for seed 1984 (1984/3001) ...
# Generating image for seed 1985 (1985/3001) ...
# Generating image for seed 1986 (1986/3001) ...
# Generating image for seed 1987 (1987/3001) ...
# Generating image for seed 1988 (1988/3001) ...
# Generating image for seed 1989 (1989/3001) ...
# Generating image for seed 1990 (1990/3001) ...
# Generating image for seed 1991 (1991/3001) ...
# Generating image for seed 1992 (1992/3001) ...
# Generating image for seed 1993 (1993/3001) ...
# Generating image for seed 1994 (1994/3001) ...
# Generating image for seed 1995 (1995/3001) ...
# Generating image for seed 1996 (1996/3001) ...
# Generating image for seed 1997 (1997/3001) ...
# Generating image for seed 1998 (1998/3001) ...
# Generating image for seed 1999 (1999/3001) ...
# Generating image for seed 2000 (2000/3001) ...
# Generating image for seed 2001 (2001/3001) ...
# Generating image for seed 2002 (2002/3001) ...
# Generating image for seed 2003 (2003/3001) ...
# Generating image for seed 2004 (2004/3001) ...
# Generating image for seed 2005 (2005/3001) ...
# Generating image for seed 2006 (2006/3001) ...
# Generating image for seed 2007 (2007/3001) ...
# Generating image for seed 2008 (2008/3001) ...
# Generating image for seed 2009 (2009/3001) ...
# Generating image for seed 2010 (2010/3001) ...
# Generating image for seed 2011 (2011/3001) ...
# Generating image for seed 2012 (2012/3001) ...
# Generating image for seed 2013 (2013/3001) ...
# Generating image for seed 2014 (2014/3001) ...
# Generating image for seed 2015 (2015/3001) ...
# Generating image for seed 2016 (2016/3001) ...
# Generating image for seed 2017 (2017/3001) ...
# Generating image for seed 2018 (2018/3001) ...
# Generating image for seed 2019 (2019/3001) ...
# Generating image for seed 2020 (2020/3001) ...
# Generating image for seed 2021 (2021/3001) ...
# Generating image for seed 2022 (2022/3001) ...
# Generating image for seed 2023 (2023/3001) ...
# Generating image for seed 2024 (2024/3001) ...
# ...
# Generating image for seed 2661 (2661/3001) ...
# Generating image for seed 2662 (2662/3001) ...
# Generating image for seed 2663 (2663/3001) ...
# Generating image for seed 2664 (2664/3001) ...
# Generating image for seed 2665 (2665/3001) ...
# Generating image for seed 2666 (2666/3001) ...
# Generating image for seed 2667 (2667/3001) ...
# Generating image for seed 2668 (2668/3001) ...
# Generating image for seed 2669 (2669/3001) ...
# Generating image for seed 2670 (2670/3001) ...
# Generating image for seed 2671 (2671/3001) ...
# Generating image for seed 2672 (2672/3001) ...
# Generating image for seed 2673 (2673/3001) ...
# Generating image for seed 2674 (2674/3001) ...
# Generating image for seed 2675 (2675/3001) ...
# Generating image for seed 2676 (2676/3001) ...
# Generating image for seed 2677 (2677/3001) ...
# Generating image for seed 2678 (2678/3001) ...
# Generating image for seed 2679 (2679/3001) ...
# Generating image for seed 2680 (2680/3001) ...
# Generating image for seed 2681 (2681/3001) ...
# Generating image for seed 2682 (2682/3001) ...
# Generating image for seed 2683 (2683/3001) ...
# Generating image for seed 2684 (2684/3001) ...
# Generating image for seed 2685 (2685/3001) ...
# Generating image for seed 2686 (2686/3001) ...
# Generating image for seed 2687 (2687/3001) ...
# Generating image for seed 2688 (2688/3001) ...
# Generating image for seed 2689 (2689/3001) ...
# Generating image for seed 2690 (2690/3001) ...
# Generating image for seed 2691 (2691/3001) ...
# Generating image for seed 2692 (2692/3001) ...
# Generating image for seed 2693 (2693/3001) ...
# Generating image for seed 2694 (2694/3001) ...
# Generating image for seed 2695 (2695/3001) ...
# Generating image for seed 2696 (2696/3001) ...
# Generating image for seed 2697 (2697/3001) ...
# Generating image for seed 2698 (2698/3001) ...
# Generating image for seed 2699 (2699/3001) ...
# Generating image for seed 2700 (2700/3001) ...
# Generating image for seed 2701 (2701/3001) ...
# Generating image for seed 2702 (2702/3001) ...
# Generating image for seed 2703 (2703/3001) ...
# Generating image for seed 2704 (2704/3001) ...
# Generating image for seed 2705 (2705/3001) ...
# Generating image for seed 2706 (2706/3001) ...
# Generating image for seed 2707 (2707/3001) ...
# Generating image for seed 2708 (2708/3001) ...
# Generating image for seed 2709 (2709/3001) ...
# Generating image for seed 2710 (2710/3001) ...
# Generating image for seed 2711 (2711/3001) ...
# Generating image for seed 2712 (2712/3001) ...
# Generating image for seed 2713 (2713/3001) ...
# Generating image for seed 2714 (2714/3001) ...
# Generating image for seed 2715 (2715/3001) ...
# Generating image for seed 2716 (2716/3001) ...
# Generating image for seed 2717 (2717/3001) ...
# Generating image for seed 2718 (2718/3001) ...
# Generating image for seed 2719 (2719/3001) ...
# Generating image for seed 2720 (2720/3001) ...
# Generating image for seed 2721 (2721/3001) ...
# Generating image for seed 2722 (2722/3001) ...
# Generating image for seed 2723 (2723/3001) ...
# Generating image for seed 2724 (2724/3001) ...
# Generating image for seed 2725 (2725/3001) ...
# Generating image for seed 2726 (2726/3001) ...
# Generating image for seed 2727 (2727/3001) ...
# Generating image for seed 2728 (2728/3001) ...
# Generating image for seed 2729 (2729/3001) ...
# Generating image for seed 2730 (2730/3001) ...
# Generating image for seed 2731 (2731/3001) ...
# Generating image for seed 2732 (2732/3001) ...
# Generating image for seed 2733 (2733/3001) ...
# Generating image for seed 2734 (2734/3001) ...
# Generating image for seed 2735 (2735/3001) ...
# Generating image for seed 2736 (2736/3001) ...
# Generating image for seed 2737 (2737/3001) ...
# Generating image for seed 2738 (2738/3001) ...
# Generating image for seed 2739 (2739/3001) ...
# Generating image for seed 2740 (2740/3001) ...
# Generating image for seed 2741 (2741/3001) ...
# Generating image for seed 2742 (2742/3001) ...
# Generating image for seed 2743 (2743/3001) ...
# Generating image for seed 2744 (2744/3001) ...
# Generating image for seed 2745 (2745/3001) ...
# Generating image for seed 2746 (2746/3001) ...
# Generating image for seed 2747 (2747/3001) ...
# Generating image for seed 2748 (2748/3001) ...
# Generating image for seed 2749 (2749/3001) ...
# Generating image for seed 2750 (2750/3001) ...
# Generating image for seed 2751 (2751/3001) ...
# Generating image for seed 2752 (2752/3001) ...
# Generating image for seed 2753 (2753/3001) ...
# Generating image for seed 2754 (2754/3001) ...
# Generating image for seed 2755 (2755/3001) ...
# Generating image for seed 2756 (2756/3001) ...
# Generating image for seed 2757 (2757/3001) ...
# Generating image for seed 2758 (2758/3001) ...
# Generating image for seed 2759 (2759/3001) ...
# Generating image for seed 2760 (2760/3001) ...
# Generating image for seed 2761 (2761/3001) ...
# Generating image for seed 2762 (2762/3001) ...
# Generating image for seed 2763 (2763/3001) ...
# Generating image for seed 2764 (2764/3001) ...
# Generating image for seed 2765 (2765/3001) ...
# Generating image for seed 2766 (2766/3001) ...
# Generating image for seed 2767 (2767/3001) ...
# Generating image for seed 2768 (2768/3001) ...
# Generating image for seed 2769 (2769/3001) ...
# Generating image for seed 2770 (2770/3001) ...
# Generating image for seed 2771 (2771/3001) ...
# Generating image for seed 2772 (2772/3001) ...
# Generating image for seed 2773 (2773/3001) ...
# Generating image for seed 2774 (2774/3001) ...
# Generating image for seed 2775 (2775/3001) ...
# Generating image for seed 2776 (2776/3001) ...
# Generating image for seed 2777 (2777/3001) ...
# Generating image for seed 2778 (2778/3001) ...
# Generating image for seed 2779 (2779/3001) ...
# Generating image for seed 2780 (2780/3001) ...
# Generating image for seed 2781 (2781/3001) ...
# Generating image for seed 2782 (2782/3001) ...
# Generating image for seed 2783 (2783/3001) ...
# Generating image for seed 2784 (2784/3001) ...
# Generating image for seed 2785 (2785/3001) ...
# Generating image for seed 2786 (2786/3001) ...
# Generating image for seed 2787 (2787/3001) ...
# Generating image for seed 2788 (2788/3001) ...
# Generating image for seed 2789 (2789/3001) ...
# Generating image for seed 2790 (2790/3001) ...
# Generating image for seed 2791 (2791/3001) ...
# Generating image for seed 2792 (2792/3001) ...
# Generating image for seed 2793 (2793/3001) ...
# Generating image for seed 2794 (2794/3001) ...
# Generating image for seed 2795 (2795/3001) ...
# Generating image for seed 2796 (2796/3001) ...
# Generating image for seed 2797 (2797/3001) ...
# Generating image for seed 2798 (2798/3001) ...
# Generating image for seed 2799 (2799/3001) ...
# Generating image for seed 2800 (2800/3001) ...
# Generating image for seed 2801 (2801/3001) ...
# Generating image for seed 2802 (2802/3001) ...
# Generating image for seed 2803 (2803/3001) ...
# Generating image for seed 2804 (2804/3001) ...
# Generating image for seed 2805 (2805/3001) ...
# Generating image for seed 2806 (2806/3001) ...
# Generating image for seed 2807 (2807/3001) ...
# Generating image for seed 2808 (2808/3001) ...
# Generating image for seed 2809 (2809/3001) ...
# Generating image for seed 2810 (2810/3001) ...
# Generating image for seed 2811 (2811/3001) ...
# Generating image for seed 2812 (2812/3001) ...
# Generating image for seed 2813 (2813/3001) ...
# Generating image for seed 2814 (2814/3001) ...
# Generating image for seed 2815 (2815/3001) ...
# Generating image for seed 2816 (2816/3001) ...
# Generating image for seed 2817 (2817/3001) ...
# Generating image for seed 2818 (2818/3001) ...
# Generating image for seed 2819 (2819/3001) ...
# Generating image for seed 2820 (2820/3001) ...
# Generating image for seed 2821 (2821/3001) ...
# Generating image for seed 2822 (2822/3001) ...
# Generating image for seed 2823 (2823/3001) ...
# Generating image for seed 2824 (2824/3001) ...
# Generating image for seed 2825 (2825/3001) ...
# Generating image for seed 2826 (2826/3001) ...
# Generating image for seed 2827 (2827/3001) ...
# Generating image for seed 2828 (2828/3001) ...
# Generating image for seed 2829 (2829/3001) ...
# Generating image for seed 2830 (2830/3001) ...
# Generating image for seed 2831 (2831/3001) ...
# Generating image for seed 2832 (2832/3001) ...
# Generating image for seed 2833 (2833/3001) ...
# Generating image for seed 2834 (2834/3001) ...
# Generating image for seed 2835 (2835/3001) ...
# Generating image for seed 2836 (2836/3001) ...
# Generating image for seed 2837 (2837/3001) ...
# Generating image for seed 2838 (2838/3001) ...
# Generating image for seed 2839 (2839/3001) ...
# Generating image for seed 2840 (2840/3001) ...
# Generating image for seed 2841 (2841/3001) ...
# Generating image for seed 2842 (2842/3001) ...
# Generating image for seed 2843 (2843/3001) ...
# Generating image for seed 2844 (2844/3001) ...
# Generating image for seed 2845 (2845/3001) ...
# Generating image for seed 2846 (2846/3001) ...
# Generating image for seed 2847 (2847/3001) ...
# Generating image for seed 2848 (2848/3001) ...
# Generating image for seed 2849 (2849/3001) ...
# Generating image for seed 2850 (2850/3001) ...
# Generating image for seed 2851 (2851/3001) ...
# Generating image for seed 2852 (2852/3001) ...
# Generating image for seed 2853 (2853/3001) ...
# Generating image for seed 2854 (2854/3001) ...
# Generating image for seed 2855 (2855/3001) ...
# Generating image for seed 2856 (2856/3001) ...
# Generating image for seed 2857 (2857/3001) ...
# Generating image for seed 2858 (2858/3001) ...
# Generating image for seed 2859 (2859/3001) ...
# Generating image for seed 2860 (2860/3001) ...
# Generating image for seed 2861 (2861/3001) ...
# Generating image for seed 2862 (2862/3001) ...
# Generating image for seed 2863 (2863/3001) ...
# Generating image for seed 2864 (2864/3001) ...
# Generating image for seed 2865 (2865/3001) ...
# Generating image for seed 2866 (2866/3001) ...
# Generating image for seed 2867 (2867/3001) ...
# Generating image for seed 2868 (2868/3001) ...
# Generating image for seed 2869 (2869/3001) ...
# Generating image for seed 2870 (2870/3001) ...
# Generating image for seed 2871 (2871/3001) ...
# Generating image for seed 2872 (2872/3001) ...
# Generating image for seed 2873 (2873/3001) ...
# Generating image for seed 2874 (2874/3001) ...
# Generating image for seed 2875 (2875/3001) ...
# Generating image for seed 2876 (2876/3001) ...
# Generating image for seed 2877 (2877/3001) ...
# Generating image for seed 2878 (2878/3001) ...
# Generating image for seed 2879 (2879/3001) ...
# Generating image for seed 2880 (2880/3001) ...
# Generating image for seed 2881 (2881/3001) ...
# Generating image for seed 2882 (2882/3001) ...
# Generating image for seed 2883 (2883/3001) ...
# Generating image for seed 2884 (2884/3001) ...
# Generating image for seed 2885 (2885/3001) ...
# Generating image for seed 2886 (2886/3001) ...
# Generating image for seed 2887 (2887/3001) ...
# Generating image for seed 2888 (2888/3001) ...
# Generating image for seed 2889 (2889/3001) ...
# Generating image for seed 2890 (2890/3001) ...
# Generating image for seed 2891 (2891/3001) ...
# Generating image for seed 2892 (2892/3001) ...
# Generating image for seed 2893 (2893/3001) ...
# Generating image for seed 2894 (2894/3001) ...
# Generating image for seed 2895 (2895/3001) ...
# Generating image for seed 2896 (2896/3001) ...
# Generating image for seed 2897 (2897/3001) ...
# Generating image for seed 2898 (2898/3001) ...
# Generating image for seed 2899 (2899/3001) ...
# Generating image for seed 2900 (2900/3001) ...
# Generating image for seed 2901 (2901/3001) ...
# Generating image for seed 2902 (2902/3001) ...
# Generating image for seed 2903 (2903/3001) ...
# Generating image for seed 2904 (2904/3001) ...
# Generating image for seed 2905 (2905/3001) ...
# Generating image for seed 2906 (2906/3001) ...
# Generating image for seed 2907 (2907/3001) ...
# Generating image for seed 2908 (2908/3001) ...
# Generating image for seed 2909 (2909/3001) ...
# Generating image for seed 2910 (2910/3001) ...
# Generating image for seed 2911 (2911/3001) ...
# Generating image for seed 2912 (2912/3001) ...
# Generating image for seed 2913 (2913/3001) ...
# Generating image for seed 2914 (2914/3001) ...
# Generating image for seed 2915 (2915/3001) ...
# Generating image for seed 2916 (2916/3001) ...
# Generating image for seed 2917 (2917/3001) ...
# Generating image for seed 2918 (2918/3001) ...
# Generating image for seed 2919 (2919/3001) ...
# Generating image for seed 2920 (2920/3001) ...
# Generating image for seed 2921 (2921/3001) ...
# Generating image for seed 2922 (2922/3001) ...
# Generating image for seed 2923 (2923/3001) ...
# Generating image for seed 2924 (2924/3001) ...
# Generating image for seed 2925 (2925/3001) ...
# Generating image for seed 2926 (2926/3001) ...
# Generating image for seed 2927 (2927/3001) ...
# Generating image for seed 2928 (2928/3001) ...
# Generating image for seed 2929 (2929/3001) ...
# Generating image for seed 2930 (2930/3001) ...
# Generating image for seed 2931 (2931/3001) ...
# Generating image for seed 2932 (2932/3001) ...
# Generating image for seed 2933 (2933/3001) ...
# Generating image for seed 2934 (2934/3001) ...
# Generating image for seed 2935 (2935/3001) ...
# Generating image for seed 2936 (2936/3001) ...
# Generating image for seed 2937 (2937/3001) ...
# Generating image for seed 2938 (2938/3001) ...
# Generating image for seed 2939 (2939/3001) ...
# Generating image for seed 2940 (2940/3001) ...
# Generating image for seed 2941 (2941/3001) ...
# Generating image for seed 2942 (2942/3001) ...
# Generating image for seed 2943 (2943/3001) ...
# Generating image for seed 2944 (2944/3001) ...
# Generating image for seed 2945 (2945/3001) ...
# Generating image for seed 2946 (2946/3001) ...
# Generating image for seed 2947 (2947/3001) ...
# Generating image for seed 2948 (2948/3001) ...
# Generating image for seed 2949 (2949/3001) ...
# Generating image for seed 2950 (2950/3001) ...
# Generating image for seed 2951 (2951/3001) ...
# Generating image for seed 2952 (2952/3001) ...
# Generating image for seed 2953 (2953/3001) ...
# Generating image for seed 2954 (2954/3001) ...
# Generating image for seed 2955 (2955/3001) ...
# Generating image for seed 2956 (2956/3001) ...
# Generating image for seed 2957 (2957/3001) ...
# Generating image for seed 2958 (2958/3001) ...
# Generating image for seed 2959 (2959/3001) ...
# Generating image for seed 2960 (2960/3001) ...
# Generating image for seed 2961 (2961/3001) ...
# Generating image for seed 2962 (2962/3001) ...
# Generating image for seed 2963 (2963/3001) ...
# Generating image for seed 2964 (2964/3001) ...
# Generating image for seed 2965 (2965/3001) ...
# Generating image for seed 2966 (2966/3001) ...
# Generating image for seed 2967 (2967/3001) ...
# Generating image for seed 2968 (2968/3001) ...
# Generating image for seed 2969 (2969/3001) ...
# Generating image for seed 2970 (2970/3001) ...
# Generating image for seed 2971 (2971/3001) ...
# Generating image for seed 2972 (2972/3001) ...
# Generating image for seed 2973 (2973/3001) ...
# Generating image for seed 2974 (2974/3001) ...
# Generating image for seed 2975 (2975/3001) ...
# Generating image for seed 2976 (2976/3001) ...
# Generating image for seed 2977 (2977/3001) ...
# Generating image for seed 2978 (2978/3001) ...
# Generating image for seed 2979 (2979/3001) ...
# Generating image for seed 2980 (2980/3001) ...
# Generating image for seed 2981 (2981/3001) ...
# Generating image for seed 2982 (2982/3001) ...
# Generating image for seed 2983 (2983/3001) ...
# Generating image for seed 2984 (2984/3001) ...
# Generating image for seed 2985 (2985/3001) ...
# Generating image for seed 2986 (2986/3001) ...
# Generating image for seed 2987 (2987/3001) ...
# Generating image for seed 2988 (2988/3001) ...
# Generating image for seed 2989 (2989/3001) ...
# Generating image for seed 2990 (2990/3001) ...
# Generating image for seed 2991 (2991/3001) ...
# Generating image for seed 2992 (2992/3001) ...
# Generating image for seed 2993 (2993/3001) ...
# Generating image for seed 2994 (2994/3001) ...
# Generating image for seed 2995 (2995/3001) ...
# Generating image for seed 2996 (2996/3001) ...
# Generating image for seed 2997 (2997/3001) ...
# Generating image for seed 2998 (2998/3001) ...
# Generating image for seed 2999 (2999/3001) ...
# Generating image for seed 3000 (3000/3001) ...

# %%
from io import StringIO 
import sys, json, zipfile, os
def zipdir(path, ziph):
    # ziph is zipfile handle
    for root, dirs, files in os.walk(path):
        for file in files:
            ziph.write(os.path.join(root, file),
                       os.path.relpath(os.path.join(root, file),
                                       os.path.join(path, '..')))

def zipit(dir_list, zip_name):
    zipf = zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED)
    for dir in dir_list:
        zipdir(dir, zipf)
    zipf.close()

dir_list = ["out"]
zipit(dir_list, 'ZipGenerated.zip')

# %% [markdown]
# # Class-wise FID
# It should take roughly 4 minutes to calculate FID for each 10000 images in total. This segment takes the generated images and compares each class with respective class in original dataset.

# %%
pip install cifar2png
# Out:
# Collecting cifar2png
#   Downloading https://files.pythonhosted.org/packages/ec/19/b92d71d4c062488308f59b53d51792e111d77caac675e40f112c6b1e7f9f/cifar2png-0.0.4.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from cifar2png) (1.19.5)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.7/dist-packages (from cifar2png) (1.0.1)
# Requirement already satisfied: Pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from cifar2png) (7.1.2)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from cifar2png) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from cifar2png) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from cifar2png) (4.41.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->cifar2png) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->cifar2png) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->cifar2png) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->cifar2png) (1.24.3)
# Building wheels for collected packages: cifar2png
#   Building wheel for cifar2png (setup.py) ... done
#   Created wheel for cifar2png: filename=cifar2png-0.0.4-cp37-none-any.whl size=5935 sha256=41beb3aab7142b90aa5da3f5601bf52a0cd5c9644bbd55a547a0c7dbe992f36f
#   Stored in directory: /root/.cache/pip/wheels/88/74/1b/879adc36940e0e572a5999df305d325778a460cbfd6555a981
# Successfully built cifar2png
# Installing collected packages: cifar2png
# Successfully installed cifar2png-0.0.4

# %%
# !cifar2png cifar10 output
# Out:
# cifar-10-python.tar.gz does not exists.
# Downloading cifar-10-python.tar.gz
# 167kKB [00:06, 25.4kKB/s]
# Saving train images: 100% 50000/50000 [00:21<00:00, 2291.79it/s]
# Saving test images: 100% 10000/10000 [00:04<00:00, 2369.53it/s]

# %%
pip install pytorch-fid
# Out:
# Collecting pytorch-fid
#   Downloading https://files.pythonhosted.org/packages/93/54/49dc21a5ee774af0390813c3cf66af57af0a31ab22ba0c2ac02cdddeb755/pytorch-fid-0.2.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.19.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.4.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.8.1+cu101)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (0.9.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.1->pytorch-fid) (3.7.4.3)
# Building wheels for collected packages: pytorch-fid
#   Building wheel for pytorch-fid (setup.py) ... done
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.0-cp37-none-any.whl size=10547 sha256=f8704012341f8c520706fa4f20a1be48616c7d8b263e74519104b5c5d8568812
#   Stored in directory: /root/.cache/pip/wheels/72/36/3c/4f3fb256f62d24bef52636f66f21667bc21caa637ce92f0e53
# Successfully built pytorch-fid
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.2.0

# %%
# !python -m pytorch_fid '/content/output/train/airplane' '/content/class0'
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 57.1MB/s]
# 100% 100/100 [00:50<00:00,  1.97it/s]
# 100% 201/201 [01:42<00:00,  1.95it/s]
# FID:  11.211684912054636

# %%
from io import StringIO 
import sys, json, zipfile, os
import numpy as np

# %%
fids = np.zeros(10, dtype=float)

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/airplane' '/content/class0' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[0] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/automobile' '/content/class1' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[1] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/bird' '/content/class2' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[2] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/cat' '/content/class3' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[3] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/deer' '/content/class4' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[4] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/dog' '/content/class5' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[5] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/frog' '/content/class6' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[6] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/horse' '/content/class7' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[7] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/ship' '/content/class8' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[8] = float(fid_string[6:])

old_stdout = sys.stdout
result = StringIO()
sys.stdout = result
# !python -m pytorch_fid '/content/output/train/truck' '/content/class9' 
sys.stdout = old_stdout
result_string = result.getvalue() 
fid_string = result_string.splitlines()[-1]
fids[9] = float(fid_string[6:])

print(fids)
# Out:
# [11.21168491  6.90122187 12.4770563  12.30474665  8.94979622 13.24031793
#  10.94682488  8.72537748  7.71672918  6.65768364]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
classes = np.array(['airplane', 'automobile', 'bird', 'cat', 'dear','dog', 'frog', 'horse', 'ship', 'truck'])
df = pd.DataFrame({'Class':classes, 'FID value':fids})

# %%
plt.figure(figsize=(10, 10))
  
# Defining the values for x-axis, y-axis
# and from which datafarme the values are to be picked
plots = sns.barplot(x="Class", y="FID value", data=df)
  
# Iterrating over the bars one-by-one
for bar in plots.patches:
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
  
# Setting the label for x-axis
plt.xlabel("Image Class", size=14)
  
# Setting the label for y-axis
plt.ylabel("FID value", size=14)
  
# Setting the title for the graph
plt.title("Classwise-FID comparison of StyleGAN2-ADA on CIFAR10 dataset")
  
# Fianlly showing the plot
plt.show()

# %% [markdown]
# # Class wise KID
#
# It should take roughly 4 minutes to calculate KID for each 10000 images in total. This segment takes the generated images and compares each class with respective class in original dataset.

# %%
# !pip install torch-fidelity==0.2.0
# !git clone 'https://github.com/toshas/torch-fidelity.git'
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/airplane /content/class0 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/automobile /content/class1 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/bird /content/class2 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/cat /content/class3
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/deer /content/class4 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/dog /content/class5 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/frog /content/class6
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/horse /content/class7 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/ship /content/class8 
# !python /content/torch-fidelity/torch_fidelity/fidelity.py --gpu 0 --kid /content/output/train/truck /content/class9
# Out:
# Collecting torch-fidelity==0.2.0
#   Downloading https://files.pythonhosted.org/packages/c9/bf/27716d7e00f18660f0955b09b04e8e52b85a3fab49f3a7fd7d015e1b8a2b/torch_fidelity-0.2.0-py3-none-any.whl
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (1.4.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from torch-fidelity==0.2.0) (0.9.1+cu101)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torch-fidelity==0.2.0) (3.7.4.3)
# Installing collected packages: torch-fidelity
# Successfully installed torch-fidelity-0.2.0
# Cloning into 'torch-fidelity'...
# remote: Enumerating objects: 518, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 518 (delta 31), reused 28 (delta 9), pack-reused 453
# Receiving objects: 100% (518/518), 278.61 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (303/303), done.
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 53.1MB/s]
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/airplane" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class0" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.001929053
# kernel_inception_distance_std: 0.000336048
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/automobile" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class1" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.0007491717
# kernel_inception_distance_std: 0.0002052874
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/bird" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class2" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.002232094
# kernel_inception_distance_std: 0.0003748082
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/cat" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class3" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.001428902
# kernel_inception_distance_std: 0.0002342513
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/deer" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class4" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.0007164741
# kernel_inception_distance_std: 0.0001809052
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/dog" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class5" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.002534912
# kernel_inception_distance_std: 0.0003763528
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/frog" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class6" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.00142872
# kernel_inception_distance_std: 0.000260147
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/horse" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class7" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.0006952117
# kernel_inception_distance_std: 0.0001313665
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/ship" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class8" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.0009077326
# kernel_inception_distance_std: 0.0002081214
# Creating feature extractor "inception-v3-compat" with features ['2048']
# Extracting features from input_1
# Looking for samples non-recursivelty in "/content/output/train/truck" with extensions png,jpg,jpeg
# Found 5000 samples
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Processing samples
# Extracting features from input_2
# Looking for samples non-recursivelty in "/content/class9" with extensions png,jpg,jpeg
# Found 3001 samples
# Processing samples
# Computing Kernel Inception Distance
# kernel_inception_distance_mean: 0.0009183534
# kernel_inception_distance_std: 0.0001653681

# %%
classes = np.array(['airplane', 'automobile', 'bird', 'cat', 'dear','dog', 'frog', 'horse', 'ship', 'truck'])
kids = np.array([ 0.001929053,0.0007491717, 0.002232094,0.001428902,0.001428902 , 0.0007164741, 0.002534912, 0.00142872, 0.0006952117, 0.0009077326 ])
df = pd.DataFrame({'Class':classes, 'KID value':kids})
plt.figure(figsize=(10, 10))
  
# Defining the values for x-axis, y-axis
# and from which datafarme the values are to be picked
plots = sns.barplot(x="Class", y="KID value", data=df)
  
# Iterrating over the bars one-by-one
for bar in plots.patches:
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.4f'), 
                   (bar.get_x() + bar.get_width() / 2, 
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
  
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

change_width(plots, 1)
# Setting the label for x-axis
plt.xlabel("Image Class", size=14)
  
# Setting the label for y-axis
plt.ylabel("KID value", size=14)
  
# Setting the title for the graph
plt.title("Classwise-KID comparison of StyleGAN2-ADA on CIFAR10 dataset")
  
# Fianlly showing the plot
plt.show()
